# %% [markdown]
# <a href="https://colab.research.google.com/github/Teluser/web-itmo/blob/master/Soft_skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Transcript youtube

# %%
with open("text.txt","r") as infile:
    lines=infile.readlines()
    news=[line for line in lines if line != "[музыка]\n"]
    print (news)
with open ("new.txt","w") as out:
    for line in news:
        out.write(line.strip()+" ")
# Out:
# ['александр питерский лингвист кандидат\n', 'филологических наук доцент института\n', 'лингвистики rgb\n', 'научный сотрудник ниу высшая школа\n', 'экономики\n', 'лауреат премии просветитель 2017 за\n', 'книгу конструирование языков от\n', 'эсперанто\n', 'до дотракийского\n', 'приветствуем александр добрый день\n', 'давненько у нас не было вопросов сегодня\n', 'давайте проведем опрос наших зрителей и\n', 'так во вопрос к тем кто нас смотрит как\n', 'связаны мышление и язык язык определяет\n', 'мышление мышление определяет язык\n', 'они взаимно влияют друг на друга это\n', 'вообще одно и тоже не как и все\n', 'определяет труд деятельность пожалуйста\n', 'перейдите по ссылке в чате и\n', 'проголосуйте друзья а я хочу задать\n', 'вопрос\n', 'вот если когда-нибудь на другой планете\n', 'возникнет или уже возникло разумная\n', 'жизнь насколько их язык отличается от\n', 'нашего\n', 'но если он вообще у них возник вопрос\n', 'которым люди активно задавались в ад и\n', 'семидесятые годы пото
# ...

# %% [markdown]
# Lab1 Os

# %%
#OS 1
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("log.txt",header=None)
y=df[0]
plt.plot(y)
plt.xlabel("Number of iterations")
plt.ylabel("Free physical memory in KB")
# Out:
# Text(0, 0.5, 'Free physical memory in KB')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("calloc.txt",delimiter=";",header=None)
x=df[0]
y=df[1]
plt.plot(x,y)
plt.xlabel("Allocated memory in Mb")
plt.ylabel("Time");
